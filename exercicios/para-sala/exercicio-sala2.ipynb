# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_olist = pd.read_csv('base_final_s14_parte2.csv')
df_olist
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 110192  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 110193  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 110194  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110195  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110196  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
df_olist.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_delivered_customer_date', 'reference_month', 'order_item_id',
#        'product_id', 'seller_id', 'shipping_limit_date', 'price',
#        'freight_value', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state'],
#       dtype='object')

# %%
df_olist['product_id'].unique()
# Out:
# array(['87285b34884572647811a353c7ac498a',
#        '595fac2a385ac33a80bd5114aec74eb8',
#        'aa4383b373c6aca5d8797843e5594415', ...,
#        '3d2c44374ee42b3003a470f3e937a2ea',
#        'ac35486adb7b02598c182c2ff2e05254',
#        '006619bbed68b000c8ba3f8725d5409e'], dtype=object)

# %%
# número de itens
df_olist['product_id'].nunique()
# Out:
# 32216

# %% [markdown]
# 1. Produtos com maior e menor preço

# %%
plt.figure(figsize=(8, 6))

sns.countplot(df_olist,
              x = 'price',
              )

plt.title('')
plt.xlabel('')
plt.ylabel('')

plt.show()

# %% [markdown]
# 2. Ranking de clientes por estado

# %%
plt.figure(figsize=(8, 6))

sns.countplot(df_olist,
              x = 'customer_state',
              )

plt.title('Ranking de clientes por estado')
plt.xlabel('Estados')
plt.ylabel('Total de vendas')

plt.show()

# %% [markdown]
# 3. Produtos mais vendidos

# %%
df_olist
