# %% [markdown]
# Imprtando as Bibliotecas:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importando os modulos:

# %%
# %run functions/data_read.ipynb  #1
# %run functions/data_path.ipynb  #2
# %run functions/data_information.ipynb #3
# %run functions/data_processing.ipynb #4
# %run functions/dataframe_join.ipynb #5

# %% [markdown]
# Leitura dos DataFrame:

# %%
df_sellers = read_data(file_path_sellers)
df_sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %% [markdown]
# Obs: Descartarei o df_sellers, pois não informações uteis para o tipo de análise a ser feita.

# %%
df_sellers.drop(df_sellers.index, inplace=True)

# %%
df_products = read_data(file_path_products)
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_orders = read_data(file_path_orders)
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_order_reviwes = read_data(file_path_order_reviwes)
df_order_reviwes
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
df_payments = read_data(file_path_payments)
df_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_items = read_data(file_path_items)
df_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_geolocation = read_data(file_path_geolocation)
df_geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# Obs: Descartarei o df_geolocation, pois não informações uteis para o tipo de análise a ser feita.

# %%
df_geolocation.drop(df_geolocation.index, inplace=True)

# %%
df_custumers = read_data(file_path_custumers)
df_custumers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# Join dos dataframe:
# 1º ['customer_id'] df_custumer e df_orders  =  df_olist_final
# 2º ['order_id] df_olist_final e df_order_rewiewa = df_olist_final

# %%
chave = "customer_id"
chave_formatada = f'{chave}'
tipo_join = 1

# %%
df_olist_final = join(df_custumers, df_orders ,chave, tipo_join)

# %%
df_olist_final
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
chave = "order_id"
chave_formatada = f'{chave}'
tipo_join = 1

# %%
df_olist_final = join(df_olist_final, df_order_reviwes ,chave, tipo_join)

# %%
df_olist_final
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99219  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99220  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99221  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99222  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99223  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
df_olist_final = join(df_olist_final, df_payments ,chave, tipo_join)

# %%
df_olist_final
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 103672  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 103673  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 103674  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 103675  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 103676  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
df_olist_final = join(df_olist_final, df_items ,chave, tipo_join)

# %%
df_olist_final
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 117324  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 117325  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 117326  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 117327  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 117328  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
chave = "product_id"
chave_formatada = f'{chave}'
tipo_join = 1

# %%
df_olist_final = join(df_olist_final, df_products ,chave, tipo_join)

# %%
df_olist_final
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 117324  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 117325  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 117326  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 117327  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 117328  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
df_olist_final_backup = df_olist_final.copy()

# %% [markdown]
# Deletando os dataframe (acredito que não fica muito pesado)

# %%
df_custumers.drop(df_custumers.index, inplace=True) 
df_items.drop(df_items.index, inplace=True) 
df_orders.drop(df_orders.index, inplace=True) 
df_order_reviwes.drop(df_order_reviwes.index, inplace=True) 
df_products.drop(df_products.index, inplace=True) 
df_payments.drop(df_payments.index, inplace=True)

# %% [markdown]
# Informações sobre os df_olist_final:

# %%
tamanho, tipo, soma_NaN, metricas = info_dataframe(df_olist_final)

# %%
tamanho
# Out:
# (117329, 36)

# %%
tipo
# Out:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# review_id                         object
# review_score                       int64
# review_comment_title              object
# review_comment_message            object
# review_creation_date              object
# review_answer_timestamp           object
# payment_sequential                 int64
# payment_type                      object
# payment_installments               int64
# payment_value                    float64
# order_item_id                      int64
# ...

# %%
soma_NaN
# Out:
# customer_id                           0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# order_id                              0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1235
# order_delivered_customer_date      2471
# order_estimated_delivery_date         0
# review_id                             0
# review_score                          0
# review_comment_title             103437
# review_comment_message            67650
# review_creation_date                  0
# review_answer_timestamp               0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# order_item_id                         0
# ...

# %%
metricas
# Out:
#                                   count unique  \
# customer_id                      117329  97916
# customer_unique_id               117329  94720
# customer_zip_code_prefix       117329.0    NaN
# customer_city                    117329   4108
# customer_state                   117329     27
# order_id                         117329  97916
# order_status                     117329      7
# order_purchase_timestamp         117329  97370
# order_approved_at                117314  89533
# order_delivered_carrier_date     116094  80449
# order_delivered_customer_date    114858  95021
# order_estimated_delivery_date    117329    449
# review_id                        117329  97708
# review_score                   117329.0    NaN
# review_comment_title              13892   4497
# review_comment_message            49679  35691
# review_creation_date             117329    632
# review_answer_timestamp          117329  97546
# payment_sequential             117329.0    NaN
# ...

# %%
lista_NaN, b_drop, msg = percentage_NaN(soma_NaN,df_olist_final)

# %%
print(b_drop)
# Out:
# True

# %%
for col, proportion in lista_NaN:
    print(f'{col} = {proportion:.2%}')
# Out:
# order_approved_at = 0.01%
# order_delivered_carrier_date = 1.05%
# order_delivered_customer_date = 2.11%
# review_comment_title = 88.16%
# review_comment_message = 57.66%
# product_category_name = 1.44%
# product_name_lenght = 1.44%
# product_description_lenght = 1.44%
# product_photos_qty = 1.44%
# product_weight_g = 0.02%
# product_length_cm = 0.02%
# product_height_cm = 0.02%
# product_width_cm = 0.02%

# %% [markdown]
# Deletando colunas que tem dados nulos > 50%

# %%
columns_drop =  ['review_comment_title','review_comment_message']

# %%
df_olist_final = df_olist_final.drop(columns_drop, axis=1)

# %%
columns_drop_def = ['review_id','customer_id','customer_unique_id','order_item_id','product_id','seller_id','customer_zip_code_prefix','customer_city','product_name_lenght','product_description_lenght','product_photos_qty']

# %%
df_olist_final = data_cleansing(df_olist_final, columns_drop_def,b_drop )

# %%
df_olist_final
# Out:
#        customer_state                          order_id order_status  \
# 0                  SP  00e7ee1b050b8499577073aeb2a297a1    delivered
# 1                  SP  29150127e6685892b6eab3eec79f59c7    delivered
# 2                  SP  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered
# 3                  SP  951670f92359f4fe4a63112aa7306eba    delivered
# 4                  SP  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered
# ...               ...                               ...          ...
# 117324             SP  6760e20addcf0121e9d58f2f1ff14298    delivered
# 117325             SP  9ec0c8947d973db4f4e8dcf1fbfa8f1b    delivered
# 117326             CE  fed4434add09a6f332ea398efd656a5c    delivered
# 117327             RS  e31ec91cea1ecf97797787471f98a8c2    delivered
# 117328             SP  28db69209a75e59f20ccbb5c36a20b90    delivered
#
#        order_purchase_timestamp    order_approved_at  \
# 0           2017-05-16 15:05:35  2017-05-16 15:22:12
# ...

# %%
df_olist_final['product_size_cm3'] = df_olist_final['product_length_cm'] * df_olist_final['product_height_cm'] * df_olist_final['product_width_cm']

# %%
df_olist_final = df_olist_final.drop(['product_length_cm','product_height_cm','product_width_cm'], axis= 1)

# %%
df_olist_final
# Out:
#        customer_state order_status   order_approved_at  \
# 0                  SP    delivered 2017-05-16 15:22:12
# 1                  SP    delivered 2018-01-12 20:58:32
# 2                  SP    delivered 2018-05-20 16:19:10
# 3                  SP    delivered 2018-03-13 17:29:19
# 4                  SP    delivered 2018-07-29 10:10:09
# ...               ...          ...                 ...
# 117324             SP    delivered 2018-04-07 16:08:45
# 117325             SP    delivered 2018-04-04 08:35:12
# 117326             CE    delivered 2018-04-08 20:30:03
# 117327             RS    delivered 2017-11-03 21:31:20
# 117328             SP    delivered 2017-12-19 18:50:39
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-05-23 10:47:57           2017-05-25 10:35:35
# 1               2018-01-15 17:14:59           2018-01-29 12:41:19
# 2               2018-06-11 14:31:00           2018-06-14 17:58:51
# ...

# %%
df_olist_final = df_olist_final.drop(['order_approval_time','order_purchase_timestamp'], axis= 1)

# %%
df_olist_final.columns
# Out:
# Index(['customer_state', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'review_score', 'review_creation_date', 'review_answer_timestamp',
#        'payment_type', 'payment_installments', 'shipping_limit_date', 'price',
#        'freight_value', 'product_category_name', 'product_weight_g',
#        'product_size_cm3'],
#       dtype='object')

# %%
cols_data = date_type(df_olist_final)
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\809702206.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_generic[col] = pd.to_datetime(df_generic[col], errors= 'raise')
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\809702206.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_generic[col] = pd.to_datetime(df_generic[col], errors= 'raise')
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\809702206.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_generic[col] = pd.to_datetime(df_generic[col], errors= 'raise')
# ...

# %%
print(cols_data)
# Out:
# ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'review_creation_date', 'review_answer_timestamp', 'shipping_limit_date']

# %% [markdown]
# Em qual setor esta o maior tempo:

# %%
df_olist_final['purchase_posting_time'] = df_olist_final['order_delivered_carrier_date'] - df_olist_final['order_approved_at']

# %%
media2 = df_olist_final['purchase_posting_time'].mean()
print(media2)
# Out:
# 2 days 20:22:28.319463468

# %%
df_olist_final['purchase_posting_time'] = df_olist_final['purchase_posting_time'].dt.days

# %%
df_olist_final['total_delivery_time'] =  df_olist_final['order_delivered_customer_date'] - df_olist_final['order_approved_at']

# %%
media3 = df_olist_final['total_delivery_time'].mean()
print(media3)
# Out:
# 12 days 00:14:32.210356748

# %%
df_olist_final['total_delivery_time'] = df_olist_final['total_delivery_time'].dt.days

# %%
df_olist_final['carrier_deliver_time'] =df_olist_final['order_delivered_customer_date'] - df_olist_final['order_delivered_carrier_date']

# %%
df_olist_final['carrier_deliver_time'] = df_olist_final['carrier_deliver_time'].dt.days

# %%
media4 = df_olist_final['carrier_deliver_time'].mean()
print(media4)
# Out:
# 9 days 03:58:52.746362868

# %%
df_tempo_medio_entrega = df_olist_final.groupby('customer_state').agg({'total_delivery_time': 'mean'})
df_tempo_medio_entrega.sort_values(by='total_delivery_time', ascending=False)
# Out:
#                 total_delivery_time
# customer_state
# RR                        27.413043
# AP                        26.890244
# AM                        25.591716
# AL                        23.542986
# PA                        22.483271
# MA                        20.428922
# SE                        20.322917
# CE                        19.800802
# AC                        19.553191
# PB                        19.236156
# RO                        18.703571
# RN                        18.667263
# PI                        18.448905
# BA                        18.161430
# PE                        17.253846
# MT                        16.851541
# TO                        16.129129
# ES                        14.623962
# MS                        14.601655
# GO                        14.368644
# RJ                        14.295279
# RS                        14.165080
# SC                        13.924376
# DF                        12.040346
# ...

# %%
df_tempo_medio_entrega = df_olist_final.groupby('customer_state').agg({'total_delivery_time': 'mean'})
df_tempo_medio_entrega = df_tempo_medio_entrega.sort_values(by='total_delivery_time', ascending=False)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df_tempo_medio_entrega, 
            x='customer_state', y='total_delivery_time', 
            palette='viridis')

# Definir título e rótulos dos eixos
plt.title('Tempo Médio de Entrega por Estado')
plt.xlabel('Estado')
plt.ylabel('Tempo Médio de Entrega (dias)')

# Rotacionar os rótulos do eixo x para melhor visualização
plt.xticks(rotation=45)

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\2528967626.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_tempo_medio_entrega,

# %%
df_tempo_medio_postagem = df_olist_final.groupby('customer_state').agg({'purchase_posting_time': 'mean'})
df_tempo_medio_postagem = df_tempo_medio_postagem.sort_values(by='purchase_posting_time', ascending=False)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df_tempo_medio_postagem, 
            x='customer_state', y='purchase_posting_time', 
            palette='rocket')

# Definir título e rótulos dos eixos
plt.title('Tempo Médio de postagem por Estado')
plt.xlabel('Estado')
plt.ylabel('Tempo Médio de Entrega (dias)')

# Rotacionar os rótulos do eixo x para melhor visualização
plt.xticks(rotation=45)

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\2749666639.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_tempo_medio_postagem,

# %%
df_tempo_medio_transportadora = df_olist_final.groupby('customer_state').agg({'carrier_deliver_time': 'mean'})
df_tempo_medio_transportadora = df_tempo_medio_transportadora.sort_values(by='carrier_deliver_time', ascending=False)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df_tempo_medio_transportadora, 
            x='customer_state', y='carrier_deliver_time', 
            palette='Paired')


plt.title('Tempo Médio de entrega da Transportadora por Estado')
plt.xlabel('Estado')
plt.ylabel('Tempo Médio de Entrega (dias)')

plt.xticks(rotation=45)


plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\364931802.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_tempo_medio_transportadora,

# %%
df_olist_final.describe().T
# Out:
#                                   count                           mean  \
# order_approved_at                117314  2017-12-30 21:58:19.189721344
# order_delivered_carrier_date     116094  2018-01-03 12:09:47.466820096
# order_delivered_customer_date    114858  2018-01-12 23:40:18.665604608
# order_estimated_delivery_date    117329  2018-01-23 07:08:36.977047552
# review_score                   117329.0                       4.031467
# review_creation_date             117329  2018-01-11 23:57:07.684545280
# review_answer_timestamp          117329  2018-01-15 03:28:45.726342400
# payment_installments           117329.0                       2.940151
# shipping_limit_date              117329  2018-01-06 02:01:32.273274368
# price                          117329.0                     120.524349
# freight_value                  117329.0                      20.027514
# product_weight_g               117309.0                    2110.763062
# ...

# %%
plt.figure(figsize=(12, 6))

ax = sns.countplot(data = df_olist_final,
              x = 'review_score',
              palette='Paired')
            

plt.title('Contagem de Avaliações')
plt.xlabel('Avaliações')
plt.ylabel('Contagem')

total = len(df_olist_final)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    ax.annotate(percentage,
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),  
                textcoords='offset points')

plt.xticks(rotation=360)
plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\2982281122.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df_olist_final,

# %%
df_olist_final.loc[df_olist_final['product_weight_g'] < 300, 'Grupo_Peso_(g)'] = '-300'
df_olist_final.loc[(df_olist_final['product_weight_g'] >= 300) & (df_olist_final['product_weight_g'] < 700), 'Grupo_Peso_(g)'] = '300-699'
df_olist_final.loc[(df_olist_final['product_weight_g'] >= 700) & (df_olist_final['product_weight_g'] < 1800), 'Grupo_Peso_(g)'] = '700-1799'
df_olist_final.loc[df_olist_final['product_weight_g'] >= 1800, 'Grupo_Peso_(g)'] = '1800+'

# %%
df_olist_final.loc[df_olist_final['product_size_cm3'] < 2856.0, 'Grupo_Tamanho_cm3'] = '- 2.856'
df_olist_final.loc[(df_olist_final['product_size_cm3'] >= 2856.0) & (df_olist_final['product_size_cm3'] < 6600.), 'Grupo_Tamanho_cm3'] = '2.856-6.599'
df_olist_final.loc[(df_olist_final['product_size_cm3'] >= 6600.0) & (df_olist_final['product_size_cm3'] < 18450.0), 'Grupo_Tamanho_cm3'] = '6.600-18.449'
df_olist_final.loc[df_olist_final['product_size_cm3'] >= 18450.0, 'Grupo_Tamanho_cm3'] = '18.450+'

# %%
media_frete = df_olist_final.groupby('Grupo_Peso_(g)').agg({'freight_value': 'mean'})
media_frete = media_frete.sort_values(by='freight_value', ascending=False)

# %%
media_frete_tamanho = df_olist_final.groupby('Grupo_Tamanho_cm3').agg({'freight_value': 'mean'})
media_frete_tamanho = media_frete_tamanho.sort_values(by='freight_value', ascending=False)

# %%
media_frete_estado = df_olist_final.groupby('customer_state').agg({'freight_value': 'mean'})
media_frete_estado =media_frete_estado.sort_values(by='freight_value', ascending=False)

# %%
plt.figure(figsize=(13, 9))
sns.barplot(data=media_frete_estado, 
            x='customer_state', y='freight_value', 
            palette='Set2')


plt.title('Peso do frete X Estado')
plt.xlabel('Estado')
plt.ylabel('Valor do frete')

plt.xticks(rotation=360)


plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\2420638199.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=media_frete_estado,

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 12))


sns.barplot(x=media_frete.index, y=media_frete['freight_value'], ax=axes[0], palette= 'tab10')
axes[0].set_title('Média do Frete por Grupo de Peso')
axes[0].set_xlabel('Grupo de Peso (g)')
axes[0].set_ylabel('Média do Frete')
axes[0].tick_params(axis='x', rotation=360)

for p in axes[0].patches:
    axes[0].annotate(format(p.get_height(), '.1f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha = 'center', va = 'center',
                     xytext = (0, 9),
                     textcoords = 'offset points')


sns.barplot(x=media_frete_tamanho.index, y=media_frete_tamanho['freight_value'], ax=axes[1], palette=  'tab10')
axes[1].set_title('Média do Frete por Grupo de Tamanho (cm³)')
axes[1].set_xlabel('Grupo de Tamanho (cm³)')
axes[1].set_ylabel('Média do Frete')
axes[1].tick_params(axis='x', rotation=360)

for p in axes[1].patches:
    axes[1].annotate(format(p.get_height(), '.1f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha = 'center', va = 'center',
                     xytext = (0, 9),
                     textcoords = 'offset points')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\1840419146.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=media_frete.index, y=media_frete['freight_value'], ax=axes[0], palette= 'tab10')
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\1840419146.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=media_frete_tamanho.index, y=media_frete_tamanho['freight_value'], ax=axes[1], palette=  'tab10')

# %%
order_vendas_categorias = df_olist_final['product_category_name'].value_counts().sort_values(ascending=False).index

# %%
plt.figure(figsize=(20, 12))


vendas_categorias = sns.countplot(data= df_olist_final,
                x = 'product_category_name',
                order = order_vendas_categorias,
                palette='Paired')

plt.title('Contagem das Categorias dos Produtos')
plt.xlabel('Categorias dos Produtos')
plt.ylabel('Contagem')

vendas_categorias.set_xticklabels(vendas_categorias.get_xticklabels(), rotation=90)

plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\939733317.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   vendas_categorias = sns.countplot(data= df_olist_final,
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\939733317.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   vendas_categorias.set_xticklabels(vendas_categorias.get_xticklabels(), rotation=90)

# %%
plt.figure(figsize=(12, 6))

ax = sns.countplot(data = df_olist_final,
              x = 'payment_type',
              palette='Paired')
            

plt.title('Contagem do tipo do Pagamento')
plt.xlabel('Tipo de Pagamento')
plt.ylabel('Contagem')

total = len(df_olist_final)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    ax.annotate(percentage,
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),  
                textcoords='offset points')

plt.xticks(rotation=360)
plt.show()
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_30352\2994852885.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df_olist_final,

# %%
df_olist_final.to_csv('base_final_s14_olist.csv', index=False)
