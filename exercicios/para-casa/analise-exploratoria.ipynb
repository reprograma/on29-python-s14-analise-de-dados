# %%
import pandas as pd

# %%
import pandas as pd

df_customers = pd.read_csv('datasets/olist_customers_dataset.csv')
df_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
import pandas as pd

df_order = pd.read_csv('datasets/olist_order_items_dataset.csv')
df_order
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
import pandas as pd

df_orders = pd.read_csv('datasets/olist_orders_dataset.csv')
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
import pandas as pd


file_path = 'datasets/olist_customers_dataset.csv'


df = pd.read_csv(file_path)


print(df.dtypes)
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
import pandas as pd


file_path = 'datasets/olist_order_items_dataset.csv'


df = pd.read_csv(file_path)


print(df.dtypes)
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
import pandas as pd


file_path = 'datasets/olist_orders_dataset.csv'


df = pd.read_csv(file_path)


print(df.dtypes)
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
import pandas as pd
import os

# Caminhos dos arquivos CSV
customers_file_path = 'datasets/olist_customers_dataset.csv'
orders_file_path = 'datasets/olist_orders_dataset.csv'
output_file_path = 'datasets/olist_customers_orders_merged.csv'

# Verificação da existência dos arquivos
if not os.path.exists(customers_file_path):
    print(f"Arquivo {customers_file_path} não encontrado.")
if not os.path.exists(orders_file_path):
    print(f"Arquivo {orders_file_path} não encontrado.")

# Leitura dos arquivos CSV
customers_df = pd.read_csv(customers_file_path)
orders_df = pd.read_csv(orders_file_path)

# União das tabelas utilizando a coluna 'customer_id'
merged_df = pd.merge(customers_df, orders_df, on='customer_id', how='inner')

# Salvando a tabela resultante em um novo arquivo CSV
merged_df.to_csv(output_file_path, index=False)

# Exibição das primeiras linhas da tabela resultante para verificar a união
print(merged_df.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
import pandas as pd
import os

# Caminhos dos arquivos CSV
customers_orders_file_path = 'datasets/olist_customers_orders_merged.csv'
items_file_path = 'datasets/olist_order_items_dataset.csv'

# Verificação da existência dos arquivos
if not os.path.exists(customers_orders_file_path):
    print(f"Arquivo {customers_orders_file_path} não encontrado.")
if not os.path.exists(items_file_path):
    print(f"Arquivo {items_file_path} não encontrado.")

# Leitura dos arquivos CSV
customers_orders_df = pd.read_csv(customers_orders_file_path)
items_df = pd.read_csv(items_file_path)

# União das tabelas utilizando a coluna 'order_id'
# Incluindo apenas a coluna 'price' do 'items_df'
final_df = pd.merge(customers_orders_df, items_df[['order_id', 'price']], on='order_id', how='left')

# Caminho para o arquivo final unificado
final_output_file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Salvando a tabela resultante em um novo arquivo CSV
final_df.to_csv(final_output_file_path, index=False)

# Exibição das primeiras linhas da tabela resultante para verificar a união
print(final_df.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
import pandas as pd

# Caminho do arquivo CSV final unificado
final_output_file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Leitura do arquivo CSV
final_df = pd.read_csv(final_output_file_path)

# Exibição dos tipos de dados das colunas
print(final_df.dtypes)
# Out:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# price                            float64
# dtype: object

# %%
import pandas as pd

# Caminho do arquivo CSV final unificado
final_output_file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Leitura do arquivo CSV
final_df = pd.read_csv(final_output_file_path)

# Exibição da quantidade de campos nulos de cada coluna
null_counts = final_df.isnull().sum()
print(null_counts)
# Out:
# customer_id                         0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# order_id                            0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 161
# order_delivered_carrier_date     1968
# order_delivered_customer_date    3229
# order_estimated_delivery_date       0
# price                             775
# dtype: int64

# %%
import pandas as pd

# Caminho do arquivo CSV final unificado
final_output_file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Leitura do arquivo CSV
final_df = pd.read_csv(final_output_file_path)

# Apagando permanentemente as colunas especificadas
columns_to_drop = ['order_delivered_carrier_date', 'order_delivered_customer_date']
final_df = final_df.drop(columns=columns_to_drop)

# Salvando o DataFrame atualizado de volta para o arquivo CSV
final_df.to_csv(final_output_file_path, index=False)

# Verificação das colunas restantes para confirmar a exclusão
print(final_df.columns)
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_estimated_delivery_date', 'price'],
#       dtype='object')

# %%
import pandas as pd

# Caminho do arquivo CSV final unificado
final_output_file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Leitura do arquivo CSV
final_df = pd.read_csv(final_output_file_path)

# Apagando as linhas que têm valores nulos na coluna 'price'
final_df = final_df.dropna(subset=['price'])

# Salvando o DataFrame atualizado de volta para o arquivo CSV
final_df.to_csv(final_output_file_path, index=False)

# Exibindo a quantidade de valores nulos para confirmar a exclusão
print(final_df.isnull().sum())
# Out:
# customer_id                       0
# customer_unique_id                0
# customer_zip_code_prefix          0
# customer_city                     0
# customer_state                    0
# order_id                          0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                15
# order_estimated_delivery_date     0
# price                             0
# dtype: int64

# %%
import pandas as pd

# Carregar o arquivo CSV
file_path = 'datasets/olist_customers_orders_items_merged.csv'
df = pd.read_csv(file_path)

# Remover linhas nulas na coluna 'order_approved_at'
df_cleaned = df.dropna(subset=['order_approved_at'])

# Salvar o DataFrame limpo de volta em um arquivo CSV
df_cleaned.to_csv(file_path, index=False)

# %%
import pandas as pd

# Carregar o arquivo CSV
file_path = 'datasets/olist_customers_orders_items_merged.csv'
df = pd.read_csv(file_path)

# Contar o número de valores nulos em cada coluna
null_counts = df.isnull().sum()

# Exibir a quantidade de linhas nulas por coluna
print(null_counts)
# Out:
# customer_id                      0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_estimated_delivery_date    0
# price                            0
# dtype: int64

# %%
import pandas as pd

# Caminhos para os arquivos CSV
file_path_orders_items = 'datasets/olist_order_items_dataset.csv'
file_path_customers_orders_items = 'datasets/olist_customers_orders_items_merged.csv'

# Carregar as planilhas
df_orders_items = pd.read_csv(file_path_orders_items)
df_customers_orders_items = pd.read_csv(file_path_customers_orders_items)

# Extrair a coluna 'product_id' da planilha 'olist_order_items_dataset'
product_id_column = df_orders_items[['product_id']]

# Adicionar a coluna 'product_id' à planilha 'olist_customers_orders_items_merged'
df_customers_orders_items = df_customers_orders_items.join(product_id_column, how='left')

# Salvar a planilha modificada
df_customers_orders_items.to_csv(file_path_customers_orders_items, index=False)

# %%
import pandas as pd

# Caminho para o arquivo CSV
file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Tentar carregar a planilha
try:
    df = pd.read_csv(file_path)
    print("Planilha carregada com sucesso.")
except Exception as e:
    print(f"Erro ao carregar a planilha: {e}")

# Verificar os tipos de dados das colunas
if 'df' in locals():
    column_types = df.dtypes
    print("\nTipos de dados das colunas:")
    print(column_types)
else:
    print("O DataFrame não foi carregado.")
# Out:
# Planilha carregada com sucesso.
#
# Tipos de dados das colunas:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_estimated_delivery_date     object
# price                            float64
# product_id                        object
# dtype: object

# %%
import pandas as pd

# Caminho para o arquivo CSV
file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Tentar carregar a planilha
try:
    df = pd.read_csv(file_path)
    print("Planilha carregada com sucesso.")
except Exception as e:
    print(f"Erro ao carregar a planilha: {e}")

# Verificar a quantidade de linhas nulas por coluna
if 'df' in locals():
    # Contar o número de valores nulos em cada coluna
    null_counts = df.isnull().sum()
    
    # Exibir a quantidade de linhas nulas por coluna
    print("\nQuantidade de linhas nulas por coluna:")
    print(null_counts)
else:
    print("O DataFrame não foi carregado.")
# Out:
# Planilha carregada com sucesso.
#
# Quantidade de linhas nulas por coluna:
# customer_id                      0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_estimated_delivery_date    0
# price                            0
# product_id                       0
# dtype: int64

# %%
import pandas as pd

# Caminho para o arquivo CSV
file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Carregar a planilha
try:
    df = pd.read_csv(file_path)
    print("Planilha carregada com sucesso.")
except Exception as e:
    print(f"Erro ao carregar a planilha: {e}")

# Verificar se o DataFrame foi carregado corretamente
if 'df' in locals():
    # Contar o número de valores únicos na coluna 'product_id'
    unique_product_ids = df['product_id'].nunique()
    
    # Exibir o número de valores únicos
    print(f"\nNúmero de valores únicos na coluna 'product_id': {unique_product_ids}")
else:
    print("O DataFrame não foi carregado.")
# Out:
# Planilha carregada com sucesso.
#
# Número de valores únicos na coluna 'product_id': 32949

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Caminho para o arquivo CSV
file_path = 'datasets/olist_customers_orders_items_merged.csv'

# Carregar a planilha
try:
    df = pd.read_csv(file_path)
    print("Planilha carregada com sucesso.")
except Exception as e:
    print(f"Erro ao carregar a planilha: {e}")

# Verificar se o DataFrame foi carregado corretamente
if 'df' in locals():
    # Agrupar por 'customer_state' e contar o número de 'order_id'
    grouped_data = df.groupby('customer_state')['order_id'].count()

    # Criar o gráfico
    plt.figure(figsize=(12, 6))
    grouped_data.plot(kind='bar', color='skyblue')
    plt.title('Número de Orders por Estado do Cliente')
    plt.xlabel('Estado do Cliente')
    plt.ylabel('Número de Orders')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Exibir o gráfico
    plt.show()
else:
    print("O DataFrame não foi carregado.")
# Out:
# Planilha carregada com sucesso.

# %%
# Carregar a planilha
try:
    df = pd.read_csv(file_path)
    print("Planilha carregada com sucesso.")
except Exception as e:
    print(f"Erro ao carregar a planilha: {e}")

# Verificar se o DataFrame foi carregado corretamente
if 'df' in locals():
    # Agrupar por 'customer_state' e somar o 'price'
    grouped_data = df.groupby('customer_state')['price'].sum()

    # Criar o gráfico
    plt.figure(figsize=(12, 6))
    grouped_data.plot(kind='bar', color='skyblue')
    plt.title('Soma dos Preços por Estado do Cliente')
    plt.xlabel('Estado do Cliente')
    plt.ylabel('Soma dos Preços')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Exibir o gráfico
    plt.show()
else:
    print("O DataFrame não foi carregado.")
# Out:
# Planilha carregada com sucesso.
