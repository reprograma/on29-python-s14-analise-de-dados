# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_olist = pd.read_csv('olist_orders_dataset (1).csv')
df_olist
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_payment = pd.read_csv('olist_order_payments_dataset.csv')
df_payment
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_olist_orders = pd.merge(df_olist, df_payment, on=['order_id'], how='inner')
df_olist_orders
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 103881  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 103882  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 103883  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 103884  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 103885  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_olist_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       103886 non-null  object
#  1   customer_id                    103886 non-null  object
#  2   order_status                   103886 non-null  object
#  3   order_purchase_timestamp       103886 non-null  object
#  4   order_approved_at              103711 non-null  object
#  5   order_delivered_carrier_date   101998 non-null  object
#  6   order_delivered_customer_date  100754 non-null  object
#  7   order_estimated_delivery_date  103886 non-null  object
#  8   payment_sequential             103886 non-null  int64
#  9   payment_type                   103886 non-null  object
#  10  payment_installments           103886 non-null  int64
#  11  payment_value                  103886 non-null  float64
# ...

# %%
df_olist_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# dtype: int64

# %%
df_olist_orders.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
df_olist_orders.describe().T
# Out:
#                          count        mean         std  min    25%    50%  \
# payment_sequential    103886.0    1.092679    0.706584  1.0   1.00    1.0
# payment_installments  103886.0    2.853349    2.687051  0.0   1.00    1.0
# payment_value         103886.0  154.100380  217.494064  0.0  56.79  100.0
#
#                            75%       max
# payment_sequential      1.0000     29.00
# payment_installments    4.0000     24.00
# payment_value         171.8375  13664.08

# %%
df_olist_orders['order_approved_at'] = pd.to_datetime(df_olist_orders['order_approved_at'])
df_olist_orders['order_delivered_carrier_date'] = pd.to_datetime(df_olist_orders['order_delivered_carrier_date'])
df_olist_orders['order_delivered_customer_date'] = pd.to_datetime(df_olist['order_delivered_customer_date'])
df_olist_orders['order_estimated_delivery_date'] = pd.to_datetime(df_olist_orders['order_estimated_delivery_date'])

# %%
# Qual a forma de pagamento mais utilizada? 
payment_type_column = df_olist_orders['payment_type']
payment_type_counts = payment_type_column.value_counts()
most_commun = payment_type_counts.idxmax()
most_commun
# Out:
# 'credit_card'

# %%
# Prof, gostaria de saber qual o mês com maior número de vendas, mas não consegui finalizar meu código. Pode me ajudar?
    #df_olist_orders['order_approved_at'] = df_olist_orders['order_status'] == 'delivered'
    #df_orders = df_olist_orders[df_olist_orders['delivered']]
    #df_orders = ['payment_type_column'] = df_orders['order_approved_at'].dt.to_period('M')
    #df_orders = ['order_status'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data = df_olist_orders,
              x= 'payment_type')

plt.title('Formas de pagamento')
plt.xlabel('payment_type')
plt.ylabel('order_approved_at')
plt.show()

# %%
df_olist_orders.to_csv('base_olist.csv', index= False)
